# %%
import pandas as pd
from importlib import reload
import script
reload(script)
from script import *

# %%
# main_df=pd.read_excel("input1.xlsx")
# main_df.head(5)
# html="<table>\n<tr>\n<th colspan=\"3\">BOOK RUNNING LEAD MANAGERS TO THE OFFER</th>\n<th></th>\n</tr>\n<tr>\n<th>kotak® Investment Banking</th>\n<th>cítì</th>\n<th>BofA SECURITIES</th>\n<th>Goldman Sachs</th>\n</tr>\n<tr>\n<td>Kotak Mahindra Capital Company Limited 1ª Floor, 27 BKC, Plot No. C - 27</td>\n<td>Citigroup Global Markets India Private Limited 1202, 12ª Floor</td>\n<td rowspan=\"2\">BofA Securities India Limited Ground Floor, \"A\" Wing, One BKC \"G\" Block Bandra Kurla Complex</td>\n<td>Goldman Sachs (India) Securities Private Limited 951-A, Rational House</td>\n</tr>\n<tr>\n<td>\"G\" Block, Bandra Kurla Complex</td>\n<td>First International Financial Center</td>\n<td>Appasaheb Marathe Marg, Prabhadevi</td>\n</tr>\n<tr>\n<td>Bandra (East)</td>\n<td>G - Block</td>\n<td>Bandra (East), Mumbai 400 051</td>\n<td>Mumbai 400 025</td>\n</tr>\n<tr>\n<td>Mumbai 400 051</td>\n<td>Bandra Kurla Complex, Bandra (East)</td>\n<td rowspan=\"3\">Maharashtra, India Tel : +91 22 6632 8000 E mail : dg.ola_electric_ipo@bofa.com</td>\n<td>Maharashtra, India</td>\n</tr>\n<tr>\n<td>Maharashtra, India</td>\n<td>Mumbai 400 098</td>\n<td>Tel: +91 22 6616 9000</td>\n</tr>\n<tr>\n<td>Tel: +91 22 4336 0000</td>\n<td>Maharashtra, India</td>\n<td>E-mail: olaevipo@gs.com</td>\n</tr>\n<tr>\n<td>E-mail: olaelectric.ipo@kotak.com</td>\n<td>Tel: +91 22 6175 9999</td>\n<td rowspan=\"5\">Website : https://business.bofa.com/bofas-india Investor Grievance ID: dg.india_merchantbanking@bofa.com Contact Person : Yash Nair SEBI Registration Number : INM000011625</td>\n<td>Website: www.goldmansachs.com</td>\n</tr>\n<tr>\n<td>Website: https://investmentbank.kotak.com</td>\n<td>E-mail: olaelectricipo@citi.com</td>\n<td rowspan=\"4\">Investor Grievance ID : india-client-support@gs.com Contact Person: Rohan Johar / Anant Gupta SEBI Registration Number: INM000011054 :</td>\n</tr>\n<tr>\n<td>Investor Grievance ID: kmccredressal@kotak.com</td>\n<td>Website:</td>\n</tr>\n<tr>\n<td rowspan=\"2\">Contact Person: Ganesh Rane SEBI Registration Number: INM000008704</td>\n<td>www.online.citibank.co.in/rhtm/citigroupglobalscreen1.htm</td>\n</tr>\n<tr>\n<td>Investor Grievance ID: investors.cgmib@citi.com Contact Person: Harsh Agarwal SEBI Registration Number: INM000010718</td>\n</tr>\n</table>"
html="<table>\n<tr>\n<th co/lspan=\"2\" rowspan=\"2\">(in billions of U.S. dollars)</th>\n<th colspan=\"2\">Fiscal</th>\n<th rowspan=\"2\">Percent Increase (Decrease) U.S. Dollars</th>\n<th rowspan=\"2\">Percent Increase (Decrease) Local Currency</th>\n</tr>\n<tr>\n<th>2023</th>\n<th>2022</th>\n</tr>\n<tr>\n<td rowspan=\"4\">Geographic Markets (1)</td>\n<td>North America</td>\n<td>$ 30.3</td>\n<td>$ 29.1</td>\n<td>4 %</td>\n<td>4 %</td>\n</tr>\n<tr>\n<td>Europe</td>\n<td>21.3</td>\n<td>20.3</td>\n<td>5</td>\n<td>11</td>\n</tr>\n<tr>\n<td>Growth Markets</td>\n<td>12.5</td>\n<td>12.2</td>\n<td>3</td>\n<td>12</td>\n</tr>\n<tr>\n<td>Total Revenues</td>\n<td>$ 64.1</td>\n<td>$ 61.6</td>\n<td>4 %</td>\n<td>8 %</td>\n</tr>\n<tr>\n<td rowspan=\"6\">Industry Groups</td>\n<td>Communications, Media &amp; Technology</td>\n<td>$ 11.5</td>\n<td>$ 12.2</td>\n<td>(6)%</td>\n<td>(3)%</td>\n</tr>\n<tr>\n<td>Financial Services</td>\n<td>12.1</td>\n<td>11.8</td>\n<td>3</td>\n<td>7</td>\n</tr>\n<tr>\n<td>Health &amp; Public Service</td>\n<td>12.6</td>\n<td>11.2</td>\n<td>12</td>\n<td>14</td>\n</tr>\n<tr>\n<td>Products</td>\n<td>19.1</td>\n<td>18.3</td>\n<td>5</td>\n<td>9</td>\n</tr>\n<tr>\n<td>Resources</td>\n<td>8.9</td>\n<td>8.1</td>\n<td>10</td>\n<td>15</td>\n</tr>\n<tr>\n<td>Total Revenues</td>\n<td>$ 64.1</td>\n<td>$ 61.6</td>\n<td>4 %</td>\n<td>8 %</td>\n</tr>\n<tr>\n<td rowspan=\"3\">Type of Work</td>\n<td>Consulting</td>\n<td>$ 33.6</td>\n<td>$ 34.1</td>\n<td>(1)%</td>\n<td>3 %</td>\n</tr>\n<tr>\n<td>Managed Services (2)</td>\n<td>30.5</td>\n<td>27.5</td>\n<td>11</td>\n<td>14</td>\n</tr>\n<tr>\n<td>Total Revenues</td>\n<td>$ 64.1</td>\n<td>$ 61.6</td>\n<td>4 %</td>\n<td>8 %</td>\n</tr>\n</table>"
# html="<table>\n<tr>\n<th rowspan=\"2\">(in billions of U.S. dollars)</th>\n<th colspan=\"2\">Fiscal</th>\n<th rowspan=\"2\">Percent Increase (Decrease) U.S. Dollars</th>\n<th rowspan=\"2\">Percent Increase (Decrease) Local Currency</th>\n</tr>\n<tr>\n<th>2023</th>\n<th>2022</th>\n</tr>\n<tr>\n<td>Consulting</td>\n<td>$ 36.2</td>\n<td>$ 37.9</td>\n<td>(4)%</td>\n<td>(1)%</td>\n</tr>\n<tr>\n<td>Managed Services (1)</td>\n<td>36.0</td>\n<td>33.9</td>\n<td>6</td>\n<td>10</td>\n</tr>\n<tr>\n<td>Total New Bookings</td>\n<td>$ 72.2</td>\n<td>$ 71.7</td>\n<td>1 %</td>\n<td>5 %</td>\n</tr>\n</table>"
# html="""<table><tr><th rowspan="2">Particulars</th><th colspan="2">For the three months ended June 30,</th><th colspan="3">Fiscals</th></tr><tr><th>2024</th><th>2023</th><th>2024</th><th>2023</th><th>2022</th></tr><tr><td>Food Delivery</td><td>15,153.40</td><td>11,926.12</td><td>51,601.25</td><td>41,299.90</td><td>33,913.14</td></tr><tr><td>Out-of-home Consumption</td><td>458.52</td><td>311.25</td><td>1,571.86</td><td>776.86</td><td>-</td></tr><tr><td>Quick Commerce</td><td>3,740.29</td><td>1,797.65</td><td>9,785.50</td><td>4,513.63</td><td>828.43</td></tr><tr><td>Supply Chain and Distribution</td><td>12,682.57</td><td>9,475.81</td><td>47,796.05</td><td>32,863.47</td><td>14,653.00</td></tr><tr><td>Platform Innovations</td><td>187.39</td><td>387.35</td><td>1,719.24</td><td>3,192.10</td><td>7,654.40</td></tr><tr><td>Total</td><td>32,222.17</td><td>23,898.18</td><td>112,473.90</td><td>82,645.96</td><td>57,048.97</td></tr></table>"""
# html="""<table>\n<tr>\n<th rowspan=\"2\">Particulars</th>\n<th colspan=\"2\">For the three months ended June 30,</th>\n<th colspan=\"3\">Fiscals</th>\n</tr>\n<tr>\n<th>2024</th>\n<th>2023</th>\n<th>2024</th>\n<th>2023</th>\n<th>2022</th>\n</tr>\n<tr>\n<td>Food Delivery</td>\n<td>15,153.40</td>\n<td>11,926.12</td>\n<td>51,601.25</td>\n<td>41,299.90</td>\n<td>33,913.14</td>\n</tr>\n<tr>\n<td>Out-of-home Consumption</td>\n<td>458.52</td>\n<td>311.25</td>\n<td>1,571.86</td>\n<td>776.86</td>\n<td>-</td>\n</tr>\n<tr>\n<td>Quick Commerce</td>\n<td>3,740.29</td>\n<td>1,797.65</td>\n<td>9,785.50</td>\n<td>4,513.63</td>\n<td>828.43</td>\n</tr>\n<tr>\n<td>Supply Chain and Distribution</td>\n<td>12,682.57</td>\n<td>9,475.81</td>\n<td>47,796.05</td>\n<td>32,863.47</td>\n<td>14,653.00</td>\n</tr>\n<tr>\n<td>Platform Innovations</td>\n<td>187.39</td>\n<td>387.35</td>\n<td>1,719.24</td>\n<td>3,192.10</td>\n<td>7,654.40</td>\n</tr>\n<tr>\n<td>Total</td>\n<td>32,222.17</td>\n<td>23,898.18</td>\n<td>112,473.90</td>\n<td>82,645.96</td>\n<td>57,048.97</td>\n</tr>\n</table>"""
# Out:
# 2
#   (in billions of U.S. dollars)                              Fiscal          \
#   (in billions of U.S. dollars)                                2023    2022
# 0        Geographic Markets (1)                       North America  $ 30.3
# 1        Geographic Markets (1)                              Europe    21.3
# 2        Geographic Markets (1)                      Growth Markets    12.5
# 3        Geographic Markets (1)                      Total Revenues  $ 64.1
# 4               Industry Groups  Communications, Media & Technology  $ 11.5
#
#   Percent Increase (Decrease) U.S. Dollars  \
#   Percent Increase (Decrease) U.S. Dollars
# 0                                   $ 29.1
# 1                                     20.3
# 2                                     12.2
# 3                                   $ 61.6
# 4                                   $ 12.2
#
#   Percent Increase (Decrease) Local Currency Unnamed: 5_level_0
#   Percent Increase (Decrease) Local Currency Unnamed: 5_level_1
# 0                                        4 %                4 %
# 1                                          5                 11
# 2                                          3                 12
# 3                                        4 %                8 %
# 4                                       (6)%               (3)%

# %%
df=main_df.copy()
row_skip, col_skip, is_text_based, symbol_matrix, all_columns, formulas = run(df)
print(formulas)
# Out:
# File successfully saved!
# [[], [], [], [], [], [1, 2, 3, 4, 5]]

# %%
print("is_text_based: ", is_text_based)
print("row_skip: ",row_skip, ", col_skip: ", col_skip)
print(len(symbol_matrix), len(symbol_matrix[0]))
# for ls in symbol_matrix:
#     print(ls)
# Out:
# is_text_based:  [True, False, False, False, False, False]
# row_skip:  1 , col_skip:  1
# 7 6

# %%
import pandas as pd
import openpyxl
from openpyxl.styles import PatternFill, Font, Alignment, Border, Side
from openpyxl.utils import get_column_letter
import io

def excel_to_html_with_style(xlsx_file_path, config):
    # Load the existing workbook
    wb = openpyxl.load_workbook(xlsx_file_path)
    ws = wb.active

    # Read the data into a DataFrame
    data = ws.values
    columns = next(data)[0:]  # Get the first row for the column headers
    main_df = pd.DataFrame(data, columns=columns)

    # Apply styles based on configuration
    header_fill = PatternFill(
        start_color=config['header']['backgroundColor'],
        end_color=config['header']['backgroundColor'],
        fill_type='solid'
    )
    header_font = Font(
        color=config['header']['fontColor'],
        bold=config['header'].get('bold', False),
        size=config['header']['fontSize'],
        name=config['font']['family']
    )
    body_font = Font(
        color=config['body']['fontColor'],
        size=config['body']['fontSize'],
        name=config['font']['family']
    )
    alignment = Alignment(
        horizontal=config['alignment']['horizontal'],
        vertical=config['alignment']['vertical'],
        wrap_text=config['alignment'].get('wrapText', True)
    )
    header_alignment = Alignment(
        horizontal=config['headeralignment']['horizontal'],
        vertical=config['headeralignment']['vertical'],
        wrap_text=config['headeralignment'].get('wrapText', True)
    )

    # Handle borders based on configuration
    if config['cell'].get('borders', True):
        border = Border(
            left=Side(style=config['cell']['borderStyle'], color=config['cell']['borderColor']),
            right=Side(style=config['cell']['borderStyle'], color=config['cell']['borderColor']),
            top=Side(style=config['cell']['borderStyle'], color=config['cell']['borderColor']),
            bottom=Side(style=config['cell']['borderStyle'], color=config['cell']['borderColor'])
        )
    else:
        border = Border()

    # Set column widths based on max length of content in each column
    for c, column in enumerate(main_df.columns, start=1):
        max_length = max(
            main_df[column].astype(str).map(len).max(),
            len(str(column))
        )
        adjusted_width = max_length + 2  # Adding extra space for padding
        ws.column_dimensions[get_column_letter(c)].width = adjusted_width  # Set column width in Excel

    # Add header row with styles
    for c, column in enumerate(main_df.columns, start=1):
        cell = ws.cell(row=1, column=c)
        cell.alignment = header_alignment
        cell.border = border
        cell.fill = header_fill
        cell.font = header_font

    # Add body rows with styles
    for r, row in enumerate(main_df.values, start=2):
        for c, value in enumerate(row, start=1):
            cell = ws.cell(row=r, column=c)
            # Preserve existing value or formula
            cell.alignment = alignment
            cell.border = border

            # Keep existing font bold for formula cells
            if cell.font.bold:  
                cell.font = Font(
                    color=body_font.color,
                    size=body_font.size,
                    name=body_font.name,
                    bold=True
                )
            else:
                cell.font = body_font

            # Check the length for wrapping and adjust alignment if needed
            if len(str(value)) > config['cell']['wrapThreshold']:
                cell.alignment = Alignment(
                    horizontal=config['alignment']['horizontal'],
                    vertical=config['alignment']['vertical'],
                    wrap_text=True  # Enable text wrapping
                )

            # Alternate row colors
            if r % 2 == 0:
                cell.fill = PatternFill(
                    start_color=config['body']['evenRowBackgroundColor'],
                    end_color=config['body']['evenRowBackgroundColor'],
                    fill_type='solid'
                )
            else:
                cell.fill = PatternFill(
                    start_color=config['body']['oddRowBackgroundColor'],
                    end_color=config['body']['oddRowBackgroundColor'],
                    fill_type='solid'
                )

    # Convert the worksheet to HTML
    output = io.StringIO()
    output.write('<table border="0" cellpadding="0" cellspacing="0" style="border-collapse: collapse;">')
    for r in range(1, ws.max_row + 1):
        output.write(f'<tr>')
        for c in range(1, ws.max_column + 1):
            cell = ws.cell(row=r, column=c)
            col_width = (ws.column_dimensions[get_column_letter(c)].width or 10) * 7  # Convert Excel units to approximate pixels
            style = (
                f'style="padding: {config["cell"]["padding"]}px; '
                f'font-family: {config["font"]["family"]}; '
                f'width: {col_width}px; '
            )

            # Add text wrapping style based on config
            if config['alignment'].get('wrapText', False):
                style += 'white-space: normal; '
            else:
                style += 'white-space: nowrap; overflow: hidden; text-overflow: ellipsis; '

            # Header styling
            if r == 1:  
                style += (
                    f'background-color: #{config["header"]["backgroundColor"]}; '
                    f'color: #{config["header"]["fontColor"]}; '
                    f'font-weight: bold; '
                    f'font-size: {config["header"]["fontSize"]}pt; '
                )
            else:  
                bg_color = (
                    config["body"]["evenRowBackgroundColor"]
                    if r % 2 == 0
                    else config["body"]["oddRowBackgroundColor"]
                )
                style += (
                    f'background-color: #{bg_color}; '
                    f'color: #{config["body"]["fontColor"]}; '
                    f'font-size: {config["body"]["fontSize"]}pt; '
                )

            # Cell borders
            if config['cell'].get('borders', True):
                style += (
                    f'border: {config["cell"]["borderStyle"]} 1px #{config["cell"]["borderColor"]}; '
                )
            else:
                style += 'border: none; '

            style += (
                f'text-align: {config["alignment"]["horizontal"]}; '
                f'vertical-align: {config["alignment"]["vertical"]}; '
                '"'
            )

            # Display value or formula
            output.write(f'<td {style}>{cell.value if cell.value is not None else ""}</td>')
        output.write('</tr>')
    output.write('</table>')
    
    return output.getvalue(), wb

# %%
import styleTable
reload(styleTable)
from styleTable import *

df=pd.read_excel('tmp.xlsx')
config_file='table_export_config.json'
output_excel_file="output1.xlsx"
config = load_config(config_file)
html, wb = excel_to_html_with_style('tmp.xlsx', config)
wb.save(output_excel_file)
print(f"Excel file saved as {output_excel_file}.")
# Out:
# 50
# Table copied to clipboard with styling. You can now paste it into Excel.
# Excel file saved as output.xlsx.
# Excel file saved as output1.xlsx.

# %%
# !pip install pyperclip
# Out:
# Collecting pyperclip
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
# Using legacy 'setup.py install' for pyperclip, since package 'wheel' is not installed.
# Installing collected packages: pyperclip
#     Running setup.py install for pyperclip: started
#     Running setup.py install for pyperclip: finished with status 'done'
# Successfully installed pyperclip-1.9.0
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'D:\ArmaanSeth\Bynd\ExcelTableCreator\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
